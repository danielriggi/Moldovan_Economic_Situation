# %%
run ../src/cap_1_code.py

# %% [markdown]
#  ### Bar Graph of GDP per Capita, PPP (constant 2011 international \\$) Moldova, Neighbors, and Larger Economies

# %%
fig, axs = plt.subplots(3,3, figsize=(25,25))
for index, ax in enumerate(axs.flatten()):
    df=df_list[index]
    title=title_list[index]
    color=color_list[index]
    plot_bar(ax=ax, df=df, x_col='Year', 
             y_col= 'GDP per capita, PPP (constant 2011 international $)',
             y_font=20,
             y_lable='GDP per capita (constant 2011)',
             x_font=23,
             title=title,
             title_font=25,
             color=color)
plt.tight_layout()

# %% [markdown]
#  ### Line Graph of GDP per Capita, PPP (constant 2011 international \\$) Moldova, and Neighbors

# %%
fig, axs = plt.subplots(1, 1, figsize=(20,10))
#plot_vert_line(ax=axs, value=1992, linestyle='--', color='red')
plot_vert_line(ax=axs, value=2008, linestyle='--', color='blue')
plot_vert_line(ax=axs, value=2014, linestyle='--', color='red')
for idx in range(len(neighbor_df_list)):
    df = neighbor_df_list[idx]
    color = color_list[idx]
    plot_line(ax=axs, df=df, x_col='Year',
              y_col='GDP per capita, PPP (constant 2011 international $)', 
              title='GDP per capita, PPP (constant 2011 international $)',
              y_label='Constant 2011 International Dollars',
              linewidth=5, alpha=.7, color=color,
              legend=neighbor_title_list_rec_sanc, xlim=(1990,2017))

# %% [markdown]
#  ### Line Graph of GDP per Capita, PPP  (constant 2011 international \\$) Moldova, Neighbors, and Large Economies

# %%
fig, axs = plt.subplots(1, 1, figsize=(20,10))
plot_vert_line(ax=axs, value=2008, linestyle='--', color='blue')
plot_vert_line(ax=axs, value=2014, linestyle='--', color='red')
for idx in range(len(df_list)):
    df = df_list[idx]
    color = color_list[idx]
    plot_line(ax=axs, df=df, x_col='Year',
              y_col='GDP per capita, PPP (constant 2011 international $)', 
              title='GDP per capita, PPP (constant 2011 international $)',
              y_label='Constant 2011 International Dollars',
              linewidth=5, alpha=.7, color=color,
              legend=title_list_rec_sanc, xlim=(1990,2017))

# %% [markdown]
#  ### Line Graph of Inflation of Consumer Prices of Moldova and Neighbors (1990-2017)

# %%
fig, axs = plt.subplots(1, 1, figsize=(20,10))
plot_vert_line(ax=axs, value=1992, linestyle='--', color='red')
plot_vert_line(ax=axs, value=1998, linestyle='--', color='blue')
plot_vert_line(ax=axs, value=1999, linestyle='--', color='green')
for idx in range(len(neighbor_df_list)):
    df = neighbor_df_list[idx]
    color = color_list[idx]
    plot_line(ax=axs, df=df, x_col='Year',
              y_col='Inflation, consumer prices (annual %)', 
              title='Inflation of Consumer Prices (annual %)',
              y_label='Inflation Annual %',
              linewidth=4, alpha=.7, color=color,legend=neighbor_title_list_fall_cris_recov, xlim=(1990,2017), ylim=(0,5000))

# %% [markdown]
#  ### Line Graph of Inflation of Consumer Prices of Moldova and Immediate Neighbors (2008-2017)

# %%
fig, axs = plt.subplots(1, 1, figsize=(20,10))
plot_vert_line(ax=axs, value=2008, linestyle='--', color='blue')
plot_vert_line(ax=axs, value=2014, linestyle='--', color='red')
for idx in range(len(neighbor_df_list_minus_bel_geo)):
    df = neighbor_df_list_minus_bel_geo[idx]
    color = color_list_minus_bel_geo[idx]
    plot_line(ax=axs, df=df, x_col='Year',
              y_col='Inflation, consumer prices (annual %)', 
              title='Inflation of Consumer Prices (annual %)',
              y_label='Inflation Annual %',
              linewidth=5, alpha=.7, color=color,legend=neighbor_title_list_minus_bel_geo_rec_sanc, xlim=(2005,2017), ylim=(-10,100))

# %% [markdown]
#  ### Line Graph of Poverty Headcount Ratio Moldova and Neighbors

# %%
fig, axs = plt.subplots(1, 1, figsize=(20,10))
plot_vert_line(ax=axs, value=1998, linestyle='--', color='blue')
plot_vert_line(ax=axs, value=1999, linestyle='--', color='green')
for idx in range(len(neighbor_df_list_poverty)):
    df = neighbor_df_list_poverty[idx]
    color = color_list_poverty[idx]
    plot_line(ax=axs, df=df, x_col='Year',
              y_col='Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)', 
              title='Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)',
              y_label='Percentage at $1.90/Day',
              linewidth=5, alpha=.7, color=color,legend=title_list_poverty, xlim=(1995,2017))

# %%
fig, axs = plt.subplots(3,3, figsize=(25,25))
for index, ax in enumerate(axs.flatten()):
    df=df_list[index]
    title=title_list[index]
    color=color_list[index]
    plot_bar(ax=ax, df=df, x_col='Year', 
             y_col= 'Inflation, consumer prices (annual %)',
             y_font=20,
             y_lable='Inflation, consumer prices (annual %))',
             x_font=23,
             title=title,
             title_font=25,
             color=color)
plt.tight_layout()

# %%
pivoted_mda.columns
# Out:
# Index(['Year', 'Access to electricity (% of population)',
#        'Age dependency ratio, old (% of working-age population)',
#        'Age dependency ratio, young (% of working-age population)',
#        'Fixed telephone subscriptions (per 100 people)',
#        'GDP per capita, PPP (constant 2011 international $)',
#        'GDP per capita, PPP (current international $)',
#        'GINI index (World Bank estimate)', 'GNI (current US$)',
#        'GNI per capita, PPP (current international $)',
#        'GNI, PPP (current international $)',
#        'Households and NPISHs Final consumption expenditure, PPP (constant 2011 international $)',
#        'Inflation, consumer prices (annual %)',
#        'International migrant stock (% of population)', 'Land area (sq. km)',
#        'Logistics performance index: Overall (1=low to 5=high)',
#        'Mobile cellular subscriptions (per 100 people)',
#        'Mortality rate, adult, female (per 1,000 female adults)',
# ...
